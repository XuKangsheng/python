# %% [markdown]
# # 商用程式設計 Chap0
#
# * holle world
# * a+b
# * requests

# %%
print('holle world')
# Out:
# holle world

# %%
print('口水會流')
# Out:
# 口水會流

# %%
a=9
b=6
a+b
# Out:
# 15

# %%
a=90
b=3
a-b
# Out:
# 87

# %%
import requests
a=requests.get('https://www.emome.net/cell_phone_plans/monthly_rate_plan/overview')
print(a.text)
# Out:
# <script>
# function line_share() {
#     var share_url = window.location.href;
#     var title = get_meta_content('og:title');
#     var description = get_meta_content('og:description');
#   if( /Android|webOS|iPhone|iPad|iPod|BlackBerry/i.test(navigator.userAgent)   ) {
#         window.open('line://msg/text/'+ title + ' '+ encodeURIComponent(share_url),"_blank","toolbar=yes,location=yes,directories=no,status=no, menubar=yes,scrollbars=yes,resizable=no, copyhistory=yes,width=600,height=400")
#     } else {
#         window.open('https://lineit.line.me/share/ui?url='+encodeURIComponent(share_url),"_blank","toolbar=yes,location=yes,directories=no,status=no, menubar=yes,scrollbars=yes,resizable=no, copyhistory=yes,width=600,height=400");
#         return false;
#     }
# }
# function get_meta_content(name) {
#     var metas = document.getElementsByTagName('meta');
#
#     for(var i = 0; i < metas.length; i++) {
#         if(metas[i].getAttribute('property') == name){
# ...
